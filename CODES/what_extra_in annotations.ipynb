# %%
from itertools import zip_longest
import glob

import pandas as pd
import numpy as np

location = '../Makarov/documents/'
file_name_list = glob.glob(location+'*.txt')
print(file_name_list)
# Out:
# ['../Makarov/documents\\AFP_ENG_20020306.0508.txt', '../Makarov/documents\\AFP_ENG_20020309.0310.txt', '../Makarov/documents\\AFP_ENG_20020311.0492.txt', '../Makarov/documents\\AFP_ENG_20020314.0244.txt', '../Makarov/documents\\AFP_ENG_20020317.0256.txt', '../Makarov/documents\\AFP_ENG_20020320.0193.txt', '../Makarov/documents\\AFP_ENG_20020321.0769.txt', '../Makarov/documents\\AFP_ENG_20020322.0480.txt', '../Makarov/documents\\AFP_ENG_20020322.0623.txt', '../Makarov/documents\\AFP_ENG_20020322.0647.txt', '../Makarov/documents\\AFP_ENG_20020322.0749.txt', '../Makarov/documents\\AFP_ENG_20020323.0092.txt', '../Makarov/documents\\AFP_ENG_20020326.0219.txt', '../Makarov/documents\\AFP_ENG_20020326.0429.txt', '../Makarov/documents\\AFP_ENG_20020326.0466.txt', '../Makarov/documents\\AFP_ENG_20020329.0134.txt', '../Makarov/documents\\AFP_ENG_20020330.0367.txt', '../Makarov/documents\\AFP_ENG_20020401.0383.txt', '../Makarov/documents\\AFP_ENG_20020407.0387.txt', '../Makarov/documents\\AFP_E
# ...

# %%
clean = [name[len(location):len(name)-4] for name in file_name_list]
print(clean)
# Out:
# ['AFP_ENG_20020306.0508', 'AFP_ENG_20020309.0310', 'AFP_ENG_20020311.0492', 'AFP_ENG_20020314.0244', 'AFP_ENG_20020317.0256', 'AFP_ENG_20020320.0193', 'AFP_ENG_20020321.0769', 'AFP_ENG_20020322.0480', 'AFP_ENG_20020322.0623', 'AFP_ENG_20020322.0647', 'AFP_ENG_20020322.0749', 'AFP_ENG_20020323.0092', 'AFP_ENG_20020326.0219', 'AFP_ENG_20020326.0429', 'AFP_ENG_20020326.0466', 'AFP_ENG_20020329.0134', 'AFP_ENG_20020330.0367', 'AFP_ENG_20020401.0383', 'AFP_ENG_20020407.0387', 'AFP_ENG_20020408.0230', 'AFP_ENG_20020408.0448', 'AFP_ENG_20020408.0478', 'AFP_ENG_20020411.0496', 'AFP_ENG_20020413.0237', 'AFP_ENG_20020416.0228', 'AFP_ENG_20020422.0284', 'AFP_ENG_20020422.0427', 'AFP_ENG_20020422.0456', 'AFP_ENG_20020422.0583', 'AFP_ENG_20020424.0134', 'AFP_ENG_20020426.0473', 'AFP_ENG_20020427.0377', 'AFP_ENG_20020429.0582', 'AFP_ENG_20030302.0506', 'AFP_ENG_20030308.0446', 'AFP_ENG_20030309.0339', 'AFP_ENG_20030325.0411', 'AFP_ENG_20030327.0111', 'AFP_ENG_20030328.0254', 'AFP_ENG_20030331.0627
# ...

# %%
location2 = '../Makarov/version20170424_changed/all/'
files2 = glob.glob(location2+'*.xml')
print(files2)
# Out:
# ['../Makarov/version20170424_changed/all\\AFP_ENG_20020306.0508.annot.xml', '../Makarov/version20170424_changed/all\\AFP_ENG_20020309.0310.annot.xml', '../Makarov/version20170424_changed/all\\AFP_ENG_20020311.0492.annot.xml', '../Makarov/version20170424_changed/all\\AFP_ENG_20020314.0244.annot.xml', '../Makarov/version20170424_changed/all\\AFP_ENG_20020317.0256.annot.xml', '../Makarov/version20170424_changed/all\\AFP_ENG_20020320.0193.annot.xml', '../Makarov/version20170424_changed/all\\AFP_ENG_20020321.0769.annot.xml', '../Makarov/version20170424_changed/all\\AFP_ENG_20020322.0480.annot.xml', '../Makarov/version20170424_changed/all\\AFP_ENG_20020322.0623.annot.xml', '../Makarov/version20170424_changed/all\\AFP_ENG_20020322.0647.annot.xml', '../Makarov/version20170424_changed/all\\AFP_ENG_20020322.0749.annot.xml', '../Makarov/version20170424_changed/all\\AFP_ENG_20020323.0092.annot.xml', '../Makarov/version20170424_changed/all\\AFP_ENG_20020326.0219.annot.xml', '../Makarov/version201
# ...

# %%
clean2 = [name[len(location2):len(name)-10] for name in files2]
print(clean2)
# Out:
# ['AFP_ENG_20020306.0508', 'AFP_ENG_20020309.0310', 'AFP_ENG_20020311.0492', 'AFP_ENG_20020314.0244', 'AFP_ENG_20020317.0256', 'AFP_ENG_20020320.0193', 'AFP_ENG_20020321.0769', 'AFP_ENG_20020322.0480', 'AFP_ENG_20020322.0623', 'AFP_ENG_20020322.0647', 'AFP_ENG_20020322.0749', 'AFP_ENG_20020323.0092', 'AFP_ENG_20020326.0219', 'AFP_ENG_20020326.0429', 'AFP_ENG_20020326.0466', 'AFP_ENG_20020329.0134', 'AFP_ENG_20020330.0367', 'AFP_ENG_20020401.0383', 'AFP_ENG_20020407.0387', 'AFP_ENG_20020408.0230', 'AFP_ENG_20020408.0448', 'AFP_ENG_20020408.0478', 'AFP_ENG_20020411.0496', 'AFP_ENG_20020413.0237', 'AFP_ENG_20020416.0228', 'AFP_ENG_20020422.0284', 'AFP_ENG_20020422.0427', 'AFP_ENG_20020422.0456', 'AFP_ENG_20020422.0583', 'AFP_ENG_20020424.0134', 'AFP_ENG_20020426.0473', 'AFP_ENG_20020427.0377', 'AFP_ENG_20020429.0582', 'AFP_ENG_20030302.0506', 'AFP_ENG_20030308.0446', 'AFP_ENG_20030309.0339', 'AFP_ENG_20030325.0411', 'AFP_ENG_20030327.0111', 'AFP_ENG_20030328.0254', 'AFP_ENG_20030331.0627
# ...

# %%
len(clean)
# Out:
# 294

# %%
len(clean2)
# Out:
# 283

# %%
#which one is not common
res = list(set(clean)^set(clean2))
res # was before ['AFP_ENG_20031003.0095'] but it was empty
# Out:
# ['APW_ENG_20030930.0296',
#  'APW_ENG_20031008.0573',
#  'AFP_ENG_20050905.0320',
#  'AFP_ENG_20060316.0663',
#  'APW_ENG_20030916.0363',
#  'AFP_ENG_20060324.0413',
#  'APW_ENG_20051028.0030',
#  'AFP_ENG_20050922.0393',
#  'APW_ENG_20060920.1310',
#  'APW_ENG_20030925.0237',
#  'APW_ENG_20031006.0533']
